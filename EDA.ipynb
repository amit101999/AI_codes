# %% [markdown]
# <a href="https://colab.research.google.com/github/amit101999/AI_codes/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd;
import seaborn as sns;

# %%
data = pd.read_csv("Titanic-Dataset.csv");

# %%
print(data.head());
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# sns.countplot(data["Survived"])
count_servived = data['Survived'].value_counts();
print(count_servived)
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
count_servived.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Numerical Data

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# BI Variant

# %%
df = pd.read_csv("tip.csv")

# %%
sns.scatterplot(data=df , x='total_bill' , y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x='Pclass', y='Fare', data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>
